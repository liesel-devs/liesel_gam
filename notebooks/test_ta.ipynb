# %% [markdown]
# # Liesel-GAM Demo Notebook

# %% [markdown]
# ## Setup and Imports

# %%
import jax.numpy as jnp
import liesel.goose as gs
import liesel.model as lsl
import numpy as np
import pandas as pd
import plotnine as p9
import tensorflow_probability.substrates.jax.distributions as tfd
import tensorflow_probability.substrates.jax.bijectors as tfb

import liesel_gam as gam

# %%
import jax

jax.config.update("jax_enable_x64", True)

# %%
def gen_tp_data(n=400, noise_sd=0.3, grid=False, seed=1):
    """
    Generate test data for tensor-product smooths with clear anisotropy.

    Parameters
    ----------
    n : int
        Number of samples (if grid=False).
    noise_sd : float
        Standard deviation of Gaussian noise.
    grid : bool
        If True, generate approximately n points on a regular grid.
        If False, generate random design points.
    seed : int
        Random seed.

    Returns
    -------
    pandas.DataFrame with columns: x, y, eta (signal), z (noisy response)
    """
    rng = np.random.default_rng(seed)

    # --- Design ----
    if grid:
        m = int(np.ceil(np.sqrt(n)))
        xs = np.linspace(0, 1, m)
        ys = np.linspace(0, 1, m)
        x, y = np.meshgrid(xs, ys, indexing="xy")
        x = x.ravel()
        y = y.ravel()
    else:
        x = rng.uniform(0, 1, n)
        y = rng.uniform(0, 1, n)

    # --- True anisotropic smooth ----
    def f_true(x, y):
        # 1) Fast variation in x, slow in y
        term1 = 1.5 * np.sin(6 * np.pi * x) * np.cos(1 * np.pi * y)

        # 2) Anisotropic Gaussian bump: elongated + rotated
        x0, y0 = 0.65, 0.35
        a_x, a_y = 0.10, 0.35  # different length scales: much tighter in x
        rho = 0.7  # correlation -> rotated ellipse

        X = x - x0
        Y = y - y0
        quad = (X**2) / (a_x**2) + (Y**2) / (a_y**2) + 2 * rho * X * Y / (a_x * a_y)
        term2 = 2.0 * np.exp(-quad)

        # 3) Mild linear trend (mainly in y for additional anisotropy)
        term3 = 0.5 * y

        return term1 + term2 + term3

    eta = f_true(x, y)
    z = eta + rng.normal(scale=noise_sd, size=len(eta))

    return pd.DataFrame({"x": x, "y": y, "eta": eta, "z": z})

# %%
df = gen_tp_data(n=600, noise_sd=0.25, grid=False, seed=42)
print(df.head())
# Out:
#           x         y       eta         z
# 0  0.773956  0.477506  0.534281  0.287991
# 1  0.438878  0.761433 -0.434527 -0.649737
# 2  0.858598  0.903328  1.107858  1.722214
# 3  0.697368  0.720696  0.093873  0.544309
# 4  0.094177  0.963211 -0.977369 -1.080306

# %%
df_grid = gen_tp_data(n=5000, grid=True)

# %%
df_grid
# Out:
#              x    y           eta         z
# 0     0.000000  0.0  3.678865e-23  0.103675
# 1     0.014286  0.0  3.990553e-01  0.645541
# 2     0.028571  0.0  7.693489e-01  0.868480
# 3     0.042857  0.0  1.084192e+00  0.693245
# 4     0.057143  0.0  1.320893e+00  1.592500
# ...        ...  ...           ...       ...
# 5036  0.942857  1.0  1.820893e+00  1.616454
# 5037  0.957143  1.0  1.584192e+00  1.591152
# 5038  0.971429  1.0  1.269349e+00  1.251839
# 5039  0.985714  1.0  8.990553e-01  0.794860
# 5040  1.000000  1.0  5.000000e-01 -0.170987
#
# [5041 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
plt.scatter(df["x"], df["y"], c=df["z"])
plt.xlabel("x")
plt.ylabel("y")
plt.title("2D Color Plot")
plt.colorbar(label="eta")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
plt.scatter(df_grid["x"], df_grid["y"], c=df_grid["z"])
plt.xlabel("x")
plt.ylabel("y")
plt.title("2D Color Plot")
plt.colorbar(label="eta")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
plt.scatter(df_grid["x"], df_grid["y"], c=df_grid["eta"])
plt.xlabel("x")
plt.ylabel("y")
plt.title("2D Color Plot")
plt.colorbar(label="eta")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Definition

# %% [markdown]
# ### Setup response model

# %%
loc = gam.AdditivePredictor("$\\mu$")
scale = gam.AdditivePredictor("$\\sigma$", inv_link=jnp.exp)


z = lsl.Var.new_obs(
    value=df.z.to_numpy(),
    distribution=lsl.Dist(tfd.Normal, loc=loc, scale=scale),
    name="z",
)

# %%
tb = gam.TermBuilder.from_df(df)

# %%
loc += tb.ps("x", k=20)
loc += tb.ps("y", k=20)

s1 = lsl.Var.new_param(
    jnp.array(1.0),
    lsl.Dist(
        tfd.Weibull,
        concentration=jnp.array(0.5),
        scale=jnp.array(1.0),
    ),
)
s2 = lsl.Var.new_param(
    jnp.array(1.0),
    lsl.Dist(
        tfd.Weibull,
        concentration=jnp.array(0.5),
        scale=jnp.array(1.0),
    ),
)
s1.transform(tfb.Softplus(), inference=gs.MCMCSpec(gs.IWLSKernel.untuned))
s2.transform(tfb.Softplus(), inference=gs.MCMCSpec(gs.IWLSKernel.untuned))

loc += tb.ta(
    tb.ps("x", k=12).basis,
    tb.ps("y", k=12).basis,
    scales=[s1, s2],
)

# %% [markdown]
# ### Build and plot model

# %%
s1.name
# Out:
# ''

# %%
s1.value_node.name
# Out:
# ''

# %%
s2.name
# Out:
# ''

# %%
model = lsl.Model([z], to_float32=False)
model.plot_vars()

# %% [markdown]
# ## Run MCMC

# %% [markdown]
# Since we used the `inference` arguments to specify MCMC kernels for all parameters above,
# we can quickly set up the MCMC engine with `gs.LieselMCMC` (new in v0.4.0).

# %%
eb = gs.LieselMCMC(model).get_engine_builder(
    seed=1, num_chains=4
)  # New in liesel v0.4.0

eb.set_epochs(
    gs.stan_epochs(
        warmup_duration=3000,
        posterior_duration=2000,
        init_duration=200,
        term_duration=200,
        thinning_posterior=5,
    )
)
engine = eb.build()
engine.sample_all_epochs()
results = engine.get_results()
# Out:
# liesel.goose.builder - WARNING - No jitter functions provided for position keys '$\\sigma$_intercept', '$\\mu$_intercept', '$\\beta_{ta1(x,y)}$', 'v1', 'v3', '$\\beta_{ps2(y)}$', '$\\tau^2$2', '$\\beta_{ps1(x)}$', '$\\tau^2$1'. The initial values for these keys won't be jittered
# liesel.goose.engine - INFO - Initializing kernels...
# liesel.goose.engine - INFO - Done
# liesel.goose.engine - INFO - Starting epoch: FAST_ADAPTATION, 200 transitions, 25 jitted together
# 100%|██████████████████████████████████████████| 8/8 [00:11<00:00,  1.38s/chunk]
# liesel.goose.engine - WARNING - Errors per chain for kernel_03: 4, 23, 4, 7 / 200 transitions
# liesel.goose.engine - WARNING - Errors per chain for kernel_04: 6, 11, 12, 6 / 200 transitions
# liesel.goose.engine - INFO - Finished epoch
# liesel.goose.engine - INFO - Starting epoch: SLOW_ADAPTATION, 25 transitions, 25 jitted together
# 100%|█████████████████████████████████████████| 1/1 [00:00<00:00, 593.51chunk/s]
# liesel.goose.engine - WARNING - Errors per chain for kernel_04: 0, 0, 1, 0 / 25 transitions
# liesel.goose.engine - INFO - Finished epoch
# liesel.goose.engine - INFO - Starting epoch: SLOW_ADAPTATION, 50 transitions, 25 jitted together
# 100%|█████████████████████████████████████████| 2/2 [00:00<00:00, 938.11chunk/s]
# liesel.goose.engine - WARNING - Errors per chain for kernel_04: 0, 2, 0, 1 / 50 transitions
# liesel.goose.engine - INFO - Finished epoch
# liesel.goose.engine - INFO - Starting epoch: SLOW_ADAPTATION, 100 transitions, 25 jitted together
# 100%|████████████████████████████████████████| 4/4 [00:00<00:00, 1179.25chunk/s]
# liesel.goose.engine - WARNING - Errors per chain for kernel_04: 0, 0, 62, 1 / 100 transitions
# liesel.goose.engine - INFO - Finished epoch
# liesel.goose.engine - INFO - Starting epoch: SLOW_ADAPTATION, 200 transitions, 25 jitted together
# 100%|█████████████████████████████████████████| 8/8 [00:00<00:00, 132.57chunk/s]
# liesel.goose.engine - WARNING - Errors per chain for kernel_04: 1, 0, 17, 16 / 200 transitions
# liesel.goose.engine - INFO - Finished epoch
# liesel.goose.engine - INFO - Starting epoch: SLOW_ADAPTATION, 400 transitions, 25 jitted together
# 100%|████████████████████████████████████████| 16/16 [00:00<00:00, 30.64chunk/s]
# liesel.goose.engine - WARNING - Errors per chain for kernel_04: 3, 2, 4, 375 / 400 transitions
# liesel.goose.engine - INFO - Finished epoch
# liesel.goose.engine - INFO - Starting epoch: SLOW_ADAPTATION, 1825 transitions, 25 jitted together
# 100%|████████████████████████████████████████| 73/73 [00:03<00:00, 18.90chunk/s]
# liesel.goose.engine - WARNING - Errors per chain for kernel_04: 15, 51, 51, 1767 / 1825 transitions
# liesel.goose.engine - INFO - Finished epoch
# liesel.goose.engine - INFO - Starting epoch: FAST_ADAPTATION, 200 transitions, 25 jitted together
# 100%|██████████████████████████████████████████| 8/8 [00:00<00:00, 56.28chunk/s]
# liesel.goose.engine - WARNING - Errors per chain for kernel_04: 1, 25, 74, 184 / 200 transitions
# liesel.goose.engine - INFO - Finished epoch
# liesel.goose.engine - INFO - Finished warmup
# liesel.goose.engine - INFO - Starting epoch: POSTERIOR, 2000 transitions, 25 jitted together
# 100%|████████████████████████████████████████| 80/80 [00:06<00:00, 12.76chunk/s]
# liesel.goose.engine - WARNING - Errors per chain for kernel_04: 12, 42, 46, 248 / 2000 transitions
# liesel.goose.engine - INFO - Finished epoch

# %% [markdown]
# ### MCMC summary

# %%
summary = gs.Summary(results)

diagnostics = (
    summary.to_dataframe()
    .reset_index()
    .loc[:, ["variable", "rhat", "ess_bulk", "ess_tail"]]
    .groupby("variable", as_index=False)
    .agg(
        ess_bulk_min=("ess_bulk", "min"),
        ess_bulk_median=("ess_bulk", "median"),
        ess_tail_min=("ess_tail", "min"),
        ess_tail_median=("ess_tail", "median"),
        rhat_max=("rhat", "max"),
        rhat_median=("rhat", "median"),
    )
)
diagnostics
# Out:
#              variable  ess_bulk_min  ess_bulk_median  ess_tail_min  \
# 0    $\beta_{ps1(x)}$    538.001020       793.864011    701.704542
# 1    $\beta_{ps2(y)}$    591.245108       794.520145    800.066700
# 2  $\beta_{ta1(x,y)}$     17.392041       427.027338    146.323942
# 3     $\mu$_intercept   1035.294272      1035.294272   1493.451099
# 4  $\sigma$_intercept    101.328227       101.328227    816.068892
# 5           $\tau^2$1    817.274804       817.274804    950.441546
# 6           $\tau^2$2    603.628241       603.628241    691.307209
# 7                  v1     14.088417        14.088417    184.476851
# 8                  v3    106.780998       106.780998     31.692802
#
#    ess_tail_median  rhat_max  rhat_median
# 0      1080.246279  1.009476     1.004224
# 1      1046.567858  1.008716     1.003572
# 2       566.311248  1.158595     1.018941
# 3      1493.451099  1.007992     1.007992
# 4       816.068892  1.032272     1.032272
# 5       950.441546  1.004185     1.004185
# 6       691.307209  1.005236     1.005236
# 7       184.476851  1.206633     1.206633
# 8        31.692802  1.040208     1.040208

# %%
gs.plot_trace(results, "$\\tau^2$5_transformed")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 gs.plot_trace(results, "$\\tau^2$5_transformed")
#
# File ~/Documents/git/liesel/src/liesel/goose/summary_viz.py:482, in plot_trace(results, params, param_indices, chain_indices, max_chains, title, title_spacing, xlabel, style, color_palette, ncol, height, aspect_ratio, save_path, include_warmup, show, **kwargs)
#     475 # NOTE: Docstring duplications
#     476 # The entries `results` to `max_chains` are shared with the `summary()`
#     477 # and all user plotting functions.
#     478 # The entries `title` to `save_path` are shared with `plot_density()`, `plot_cor()`
#     479 # and partially with `plot_param()`.
#     481 sns.set_theme(style=style)
# --> 482 plot_df = _setup_plot_df(
#     483     results, params, param_indices, chain_indices, max_chains, include_warmup
#     484 )
#     486 g = sns.relplot(
#     487     data=plot_df,
#     488     kind="line",
#    (...)    498     **kwargs,
#     499 )
#     501 g = _set_aesthetics(g, title, title_spacing, xlabel, ylabel="")
#
# File ~/Documents/git/liesel/src/liesel/goose/summary_viz.py:298, in _setup_plot_df(results, params, param_indices, chain_indices, max_chains, include_warmup)
#     288 def _setup_plot_df(
#     289     results: SamplingResults | dict[str, Array],
#     290     params: str | list[str] | None,
#    (...)    294     include_warmup: bool = False,
#     295 ) -> pd.DataFrame:
#     296     """Provides data input for all plotting functions."""
# --> 298     return _collect_param_dfs(
#     299         results,
#     300         params,
#     301         param_indices,
#     302         chain_indices,
#     303         max_chains,
#     304         include_warmup,
#     305     ).astype({"chain_index": "category"})
#
# File ~/Documents/git/liesel/src/liesel/goose/summary_viz.py:276, in _collect_param_dfs(results, params, param_indices, chain_indices, max_chains, include_warmup)
#     273 else:
#     274     samples = results.get_posterior_samples()
# --> 276 params = _validate_params(samples, params)
#     278 return pd.concat(
#     279     [
#     280         _collect_subparam_dfs(
#    (...)    284     ]
#     285 ).reset_index(drop=True)
#
# File ~/Documents/git/liesel/src/liesel/goose/summary_viz.py:120, in _validate_params(posterior_samples, params)
#     117     params = [params]
#     119 if any(param not in posterior_keys for param in params):
# --> 120     raise KeyError(f"All params must be in {posterior_keys}.")
#     122 return params
#
# KeyError: "All params must be in ['$\\\\beta_{ps1(x)}$', '$\\\\beta_{ps2(y)}$', '$\\\\beta_{ta1(x,y)}$', '$\\\\mu$_intercept', '$\\\\sigma$_intercept', '$\\\\tau^2$1', '$\\\\tau^2$2', 'v1', 'v3']."

# %%
gs.plot_trace(results, "$\\tau^2$6_transformed")

# %%
samples = results.get_posterior_samples()
predicted_tau = model.predict(samples, predict=["$\\tau^2$6", "$\\tau$6"])

# %%
gs.plot_trace(predicted_tau)

# %% [markdown]
# ### MCMC trace plots

# %% [markdown]
# ## Predictions

# %%
samples = results.get_posterior_samples()

# %% [markdown]
# ### Predict variables at new x values

# %%
predictions = model.predict(  # new in liesel v0.4.0
    samples=samples,
    predict=["ta1(x,y)", "$\\mu$", "ps1(x)", "ps2(y)"],
    newdata={"x": df_grid.x.to_numpy(), "y": df_grid.y.to_numpy()},
)

predictions_summary = (
    gs.SamplesSummary(predictions).to_dataframe().reset_index()
)  # new in liesel v0.4.0

# %%
predictions_summary["x"] = np.tile(df_grid.x.to_numpy(), len(predictions))
predictions_summary["y"] = np.tile(df_grid.y.to_numpy(), len(predictions))

# %%
predictions_summary.head()
# Out:
#   variable   var_fqn var_index  sample_size      mean       var        sd  \
# 0    $\mu$  $\mu$[0]      (0,)         1600  0.064581  0.515424  0.717930
# 1    $\mu$  $\mu$[1]      (1,)         1600  0.451373  0.308624  0.555540
# 2    $\mu$  $\mu$[2]      (2,)         1600  0.873779  0.197621  0.444546
# 3    $\mu$  $\mu$[3]      (3,)         1600  1.268569  0.133448  0.365305
# 4    $\mu$  $\mu$[4]      (4,)         1600  1.583129  0.093251  0.305370
#
#      ess_bulk    ess_tail  mcse_mean   mcse_sd      rhat    q_0.05     q_0.5  \
# 0  271.180496  656.165912   0.043610  0.021921  1.007037 -1.092664  0.077237
# 1  280.238277  531.504471   0.033147  0.017253  1.005859 -0.449460  0.447989
# 2  295.691199  531.080318   0.025849  0.013874  1.004902  0.118510  0.879455
# 3  307.306322  535.756471   0.020815  0.011434  1.004134  0.657123  1.273899
# 4  314.976943  520.154194   0.017240  0.009859  1.003399  1.086545  1.588575
#
#      q_0.95   hdi_low  hdi_high         x    y
# 0  1.240467 -1.105621  1.226804  0.000000  0.0
# 1  1.359266 -0.454804  1.336850  0.014286  0.0
# 2  1.567921  0.157227  1.597995  0.028571  0.0
# 3  1.842950  0.692909  1.861523  0.042857  0.0
# 4  2.075613  1.075831  2.058677  0.057143  0.0

# %% [markdown]
# ### Plot fitted functions

# %%
select = predictions_summary["variable"].isin(["ta1(x,y)"])
(p9.ggplot(predictions_summary[select]) + p9.geom_tile(p9.aes("x", "y", fill="mean")))

# %%
select = predictions_summary["variable"].isin(["$\\mu$"])
(p9.ggplot(predictions_summary[select]) + p9.geom_tile(p9.aes("x", "y", fill="mean")))

# %%
select = predictions_summary["variable"].isin(["ps1(x)"])
(
    p9.ggplot(predictions_summary[select])
    + p9.geom_ribbon(
        p9.aes("x", ymin="q_0.05", ymax="q_0.95", fill="variable"), alpha=0.3
    )
    + p9.geom_line(p9.aes("x", "mean"))
    + p9.facet_wrap("~variable", scales="free_y", ncol=1)
    + p9.guides(fill="none")
)

# %%
select = predictions_summary["variable"].isin(["ps2(y)"])
(
    p9.ggplot(predictions_summary[select])
    + p9.geom_ribbon(
        p9.aes("y", ymin="q_0.05", ymax="q_0.95", fill="variable"), alpha=0.3
    )
    + p9.geom_line(p9.aes("y", "mean"))
    + p9.facet_wrap("~variable", scales="free_y", ncol=1)
    + p9.guides(fill="none")
)
